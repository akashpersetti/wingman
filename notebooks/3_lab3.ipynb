# %% [markdown]
# ## Welcome to Week 4, Day 4
#
# This is the start of an AWESOME project! Really simple and very effective.

# %%
from typing import Annotated
from typing_extensions import TypedDict
from langgraph.graph import StateGraph, START
from langgraph.graph.message import add_messages
from dotenv import load_dotenv
from IPython.display import Image, display
import gradio as gr
from langgraph.prebuilt import ToolNode, tools_condition
import requests
import os
from langchain.agents import Tool

from langchain_openai import ChatOpenAI
from langgraph.checkpoint.memory import MemorySaver

# %%
load_dotenv(override=True)
# Out:
# True

# %% [markdown]
# ### Asynchronous LangGraph
#
# To run a tool:
# Sync: `tool.run(inputs)`
# Async: `await tool.arun(inputs)`
#
# To invoke the graph:
# Sync: `graph.invoke(state)`
# Async: `await graph.ainvoke(state)`

# %%
class State(TypedDict):
    
    messages: Annotated[list, add_messages]


graph_builder = StateGraph(State)

# %%
pushover_token = os.getenv("PUSHOVER_TOKEN")
pushover_user = os.getenv("PUSHOVER_USER")
pushover_url = "https://api.pushover.net/1/messages.json"

def push(text: str):
    """Send a push notification to the user"""
    requests.post(pushover_url, data = {"token": pushover_token, "user": pushover_user, "message": text})

tool_push = Tool(
        name="send_push_notification",
        func=push,
        description="useful for when you want to send a push notification"
    )

# %% [markdown]
# ## Extra installation step - if you don't have Node and Playwright on your computer
#
# Next, you need to install NodeJS and Playwright on your computer if you don't already have them. Please see instructions here:
#
# [Node and Playwright setup](../setup/SETUP-node.md)

# %% [markdown]
# ## And now - after Installing Playwright, a heads up for Windows PC Users:
#
# While executing the next few cells, you might hit a problem with the Playwright browser raising a NotImplementedError.
#
# This should work when we move to python modules, but it can cause problems in Windows in a notebook.
#
# If you it this error and would like to run the notebook, you need to make a small change which seems quite hacky! You need to do this AFTER installing Playwright (prior cells)
#
# 1. Right click in `.venv` in the File Explorer on the left and select "Find in folder"
# 2. Search for `asyncio.set_event_loop_policy(WindowsSelectorEventLoopPolicy())`
# 3. That code should be found in a line of code in a file called `kernelapp.py`
# 4. Comment out the entire else clause that this line is a part of - see the fragment below. Be sure to have the "pass" statement after the ImportError line.
# 5. Restart the kernel by pressing the "Restart" button above
#
# ```python
#         if sys.platform.startswith("win") and sys.version_info >= (3, 8):
#             import asyncio
#
#             try:
#                 from asyncio import WindowsProactorEventLoopPolicy, WindowsSelectorEventLoopPolicy
#             except ImportError:
#                 pass
#                 # not affected
#            # else:
#             #    if type(asyncio.get_event_loop_policy()) is WindowsProactorEventLoopPolicy:
#                     # WindowsProactorEventLoopPolicy is not compatible with tornado 6
#                     # fallback to the pre-3.8 default of Selector
#                     # asyncio.set_event_loop_policy(WindowsSelectorEventLoopPolicy())
# ```
#
# Thank you to student Nicolas for finding this, and to Kalyan, Yaki, Zibin and Bhaskar for confirming that this worked for them! And to Vladislav for the extra pointers.
#
# As an alternative, you can just move to a Python module (which we do anyway in Day 5)

# %%
# Introducing nest_asyncio
# Python async code only allows for one "event loop" processing aynchronous events.
# The `nest_asyncio` library patches this, and is used for special situations, if you need to run a nested event loop.

import nest_asyncio
nest_asyncio.apply()

# %% [markdown]
# ### The LangChain community
#
# One of the remarkable things about LangChain is the rich community around it.
#
# Check this out:

# %%
from langchain_community.agent_toolkits import PlayWrightBrowserToolkit
from langchain_community.tools.playwright.utils import create_async_playwright_browser

# If you get a NotImplementedError here or later, see the Heads Up at the top of the notebook

async_browser =  create_async_playwright_browser(headless=False)  # headful mode
toolkit = PlayWrightBrowserToolkit.from_browser(async_browser=async_browser)
tools = toolkit.get_tools()

# %%
for tool in tools:
    print(f"{tool.name}={tool}")
# Out:
# click_element=async_browser=<Browser type=<BrowserType name=chromium executable_path=/Users/akashhp/Library/Caches/ms-playwright/chromium-1187/chrome-mac/Chromium.app/Contents/MacOS/Chromium> version=140.0.7339.16>
# navigate_browser=async_browser=<Browser type=<BrowserType name=chromium executable_path=/Users/akashhp/Library/Caches/ms-playwright/chromium-1187/chrome-mac/Chromium.app/Contents/MacOS/Chromium> version=140.0.7339.16>
# previous_webpage=async_browser=<Browser type=<BrowserType name=chromium executable_path=/Users/akashhp/Library/Caches/ms-playwright/chromium-1187/chrome-mac/Chromium.app/Contents/MacOS/Chromium> version=140.0.7339.16>
# extract_text=async_browser=<Browser type=<BrowserType name=chromium executable_path=/Users/akashhp/Library/Caches/ms-playwright/chromium-1187/chrome-mac/Chromium.app/Contents/MacOS/Chromium> version=140.0.7339.16>
# extract_hyperlinks=async_browser=<Browser type=<BrowserType name=chromium executable_path=/Users/akashhp/Library/Caches/ms-playwright/chromium-1187/chrome-mac/Chromium.app/Contents/MacOS/Chromium> version=140.0.7339.16>
# get_elements=async_browser=<Browser type=<BrowserType name=chromium executable_path=/Users/akashhp/Library/Caches/ms-playwright/chromium-1187/chrome-mac/Chromium.app/Contents/MacOS/Chromium> version=140.0.7339.16>
# current_webpage=async_browser=<Browser type=<BrowserType name=chromium executable_path=/Users/akashhp/Library/Caches/ms-playwright/chromium-1187/chrome-mac/Chromium.app/Contents/MacOS/Chromium> version=140.0.7339.16>

# %%
tool_dict = {tool.name:tool for tool in tools}

navigate_tool = tool_dict.get("navigate_browser")
extract_text_tool = tool_dict.get("extract_text")

    
await navigate_tool.arun({"url": "https://www.cnn.com"})
text = await extract_text_tool.arun({})

# %%
import textwrap
print(textwrap.fill(text))
# Out:
# Breaking News, Latest News and Videos | CNN CNN values your feedback
# 1. How relevant is this ad to you? 2. Did you encounter any technical
# issues? No Video player was slow to load content Video content never
# loaded Ad froze or did not finish loading Video content did not start
# after ad Audio on ad was too loud Other issues Ad never loaded Ad
# prevented/slowed the page from loading Content moved around while ad
# loaded Ad was repetitive to ads I've seen previously Other issues
# Cancel Submit Thank You! Your effort and contribution in providing
# this feedback is much
# appreciated. Close Ad Feedback Close icon US World Politics Business
# Health Entertainment Underscored Style Travel Sports Science Climate
# Weather Winter Olympics 2026 Ukraine-Russia War Israel-Hamas War Games
# More US World Politics Business Health Entertainment Underscored Style
# Travel Sports Science Climate Weather Winter Olympics 2026 Ukraine-
# Russia War Israel-Hamas War Games Click to shop the best deals on tech
# appliances, home and more. close dialog Live TV has a new home Get
# unlimited streaming, including live TV, 24/7 news, shows, films, and
# more all in one place. close dialog close dialog New close dialog
# Watch Listen Subscribe Sign in My Account Settings Newsletters Topics
# you follow Sign out Your CNN account Sign in to your CNN account Sign
# in My Account Settings Newsletters Topics you follow Sign out Your CNN
# account Sign in to your CNN account Listen Watch Edition US
# International Arabic Español Edition US International Arabic Español
# US Crime & Justice Immigration Education Transportation Race &
# Identity World Africa Americas Asia Australia China Europe India
# Middle East United Kingdom Politics Trump Facts First CNN Polls 2026
# Elections Calendar Redistricting Tracker Epstein Files Business Tech
# Media Calculators Videos Markets Pre-markets After-Hours Fear & Greed
# Investing Markets Now Nightcap Health Life, But Better Fitness Food
# Sleep Mindfulness Relationships CNN Underscored Electronics Fashion
# Beauty Health & Fitness Home Reviews Deals Gifts Travel Outdoors Pets
# Entertainment Movies Television Celebrity Tech Innovate Style Arts
# Design Fashion Architecture Luxury Beauty Video Travel Destinations
# Food & Drink Stay Videos Sports Pro Football College Football
# Basketball Baseball Soccer Olympics Hockey Science Space Life
# Unearthed Climate Solutions Weather Weather Video Climate Winter
# Olympics 2026 Ukraine-Russia War Israel-Hamas War Watch Featured Shows
# & Films Network TV Clips CNN Headlines CNN Shorts Shows A-Z CNN 10 CNN
# TV Schedules Listen CNN 5 Things Chasing Life with Dr. Sanjay Gupta
# The Assignment with Audie Cornish One Thing Tug of War CNN Political
# Briefing The Axe Files All There Is with Anderson Cooper All CNN Audio
# podcasts Games Daily Crossword Jumble Crossword Photo Shuffle
# Sudoblock Sudoku 5 Things Quiz About CNN Subscribe Photos
# Investigations CNN Profiles CNN Leadership CNN Newsletters Work for
# CNN Follow CNN Download the CNN App Download the CNN App Happening Now
# Middle East conflict expands as President Trump warns Iran of bigger
# strikes. Follow the latest reaction and analysis. Trump tells CNN ‘big
# wave’ yet to come in war with Iran • CNN Exclusive 6:25 CNN CNN
# Exclusive ‘How can they justify this?’: Iranian deputy foreign
# minister on US-Israel strikes 6:25 • Video 1:10 Social Media Video US
# fighter jet crashes in Kuwait after being hit by ‘friendly fire’ 1:10
# CNN Visualizing the attack on Iran and retaliation in maps and charts
# Sirens replace celebrations as Israelis head to shelters on religious
# holiday Play Preview ends in 00:00 Keep Watching Subtitles Off Watch
# CNN’s coverage of the strikes • Source: CNN Live Updates Live Updates:
# The president says the US military is ‘knocking the crap’ out of Iran
# as the war spirals across the Middle East Here is the full readout
# from CNN’s interview with Trump on Iran CNN Poll 59% of Americans
# disapprove of Iran strikes and most think a long-term conflict is
# likely Video ‘Significant escalation’: Journalist on Qatar shooting
# down Iranian aircraft 0:36 US war with Iran draws in other countries,
# sparking fears for the global economy Live Updates 12 min ago Adviser
# to Iran's IRGC warns vessels passing through Strait of Hormuz will be
# set "on fire" 1 min ago Thune expects to hear admin's legal case for
# strikes and says Congress' OK wasn't needed 18 min ago US death toll
# from attack in Kuwait rises to 6, US military says 20 min ago
# Democratic leaders are whipping war powers vote later this week in
# effort to rebuke Trump 28 min ago Top Iran officials: Tehran is “not
# shaken” amid the war in the Mideast. Here’s the latest See all updates
# ( 145 +) Spencer Platt/Getty Images US stocks recover, gold rises and
# oil surges as war with Iran spreads What you should expect to pay for
# gas as the war with Iran continues How Middle East airspace closures
# are reshaping global aviation Video Cruise ships stranded in Doha as
# travel grinds to a halt 0:54 • CNN Investigates 2:41 CNN CNN
# Investigates Inside the precision strikes that shattered Iran’s
# leadership 2:41 Analysis The Trump team can’t get its story straight
# on war with Iran Video ‘I don’t think they know what they are doing’:
# Iraq War veteran denounces Trump case for war with Iran 5:39 Streaming
# Now CNN The United States vs. Iran: A Fareed Zakaria Special CNN The
# real woman behind the ‘People’s Princess’ CNN Step into a time machine
# and explore this totally rad decade • Live Live CNN Live Watch CNN
# More Top Stories Play Subtitles Off CNN Headlines • Source: CNN
# Breaking News Catch up on today’s headlines • Breaking News Breaking
# News Getty Images/X Breaking News House Oversight Committee releases
# video of Clinton depositions on Epstein Trump administration drops
# suits against law firms with ties to Democrats and other Trump foes
# Doctor: Trump’s neck rash is because of ‘preventative skin treatment’
# For Subscribers Hospitals are making cuts after ‘big beautiful bill,’
# fueling Democrats’ midterm attacks CardCritics Thousands rush to 0%
# APR for 18 months Texas Shooting • Breaking News Breaking News Brandon
# Bell/Getty Images Breaking News Victims identified in Austin mass
# shooting that officials say may have been motivated by Iran strikes
# Video Gunshots ring out in Austin bar district 1:20 state primaries
# Rachel Jessen/Bloomberg/Getty Images 8 big questions on the first
# primary day of 2026 • Video 8:36 Getty Images Video Why Texas primary
# could determine next Senate majority 8:36 Ad Feedback Ad Feedback CNN
# Underscored Maxwell Shukuya/CNN Underscored Upgrade your food
# containers with 41% off Ello Duraglass, plus more best sales Mar 2,
# 2026 Mike Andronico/CNN Underscored Apple just revealed the iPad Air
# M4. Its price might be its best feature Mar 2, 2026 Molly Flores/CNN
# Underscored 20 Amazon products our readers couldn’t stop adding to
# their cart last month Mar 2, 2026 Ad Feedback Check these out Alain
# Jocard/AFP/Getty Images Jim Carrey’s face is up for debate. No,
# seriously Vianney Le Caer/Shutterstock Zendaya and Tom Holland got
# married in secret, stylist says Patrick T. Fallon/AFP/Getty Images A
# total lunar eclipse will turn the moon red. Here’s how to watch •
# Video 2:38 CNN Video This solar panel blooms every morning 2:38 •
# Streaming Now Streaming Now Kate Jones Photo Streaming Now These
# ‘Friday Night Lights’ stars sit down in a candid 1-on-1 interview
# Murder trials • Live Live Pool Live Analysts break down closing
# arguments in Colin Gray trial Live Trial resumes for woman accused of
# fatally poisoning her husband Actor Awards AP/Getty Images The most
# striking looks from the red carpet Michael Buckner/Variety/Getty
# Images Actor Awards 2026: See who won • Video 1:03 Getty Images Video
# Teyana Taylor’s standout gown 1:03 For Subscribers • For Subscribers
# For Subscribers CNN For Subscribers He killed the man accused of
# sexually abusing his teenage daughter. He’s awaiting trial — and
# running for sheriff • Analysis Analysis Kevin Dietsch/Getty Images
# Analysis Trump’s new tariffs rely on an untested section of a 1974 law
# that may be illegal. It might not matter • For Subscribers For
# Subscribers Rebecca Noble/Reuters For Subscribers One month into Nancy
# Guthrie’s disappearance, three questions hang over the investigation •
# Analysis Analysis Vahid Salemi/AP Analysis Iran after strikes:
# Tactical success, strategic uncertainty Ad Feedback Ad Feedback CNN
# Underscored BEST-IN-CLASS Mike Andronico/CNN Underscored Apple’s new
# $599 iPhone looks seriously impressive I’ve worn cheap earplugs to
# sleep for over a decade. I wish Loop’s Dream earplugs had come out
# years ago Pokémon’s first life-simulation game has arrived. Here’s
# what I thought after playing it Apple's original AirTags are on sale
# for as little as $16 apiece this week I finally got the slim toaster
# I’ve been eyeing for a year, and it takes up practically zero counter
# space Expert-Backed Guides Molly Flores/CNN Underscored A bra
# shouldn’t be a pain to wear. We found 3 bras that passed our comfort
# test L.L.Bean just took up to 51% off spring apparel and its iconic
# Boat and Tote Want to block out bedroom window light to get better
# sleep? This blackout curtain we tested can help Not all USB-C chargers
# are the same. Here are the 4 best we tested Yes, eye cream makes a
# difference. We found 3 that help with wrinkles, hydration and dark
# circles Editors' picks Maxwell Shukuya/CNN Underscored Lodge’s Cast-
# Iron Skillet will be the best $20 you’ve ever spent. Here’s why If
# you’re going to buy cheap bed pillows from Amazon, make it this hotel-
# quality set We found 39 travel accessories to add to your spring break
# packing list I’m a running coach who swears by max-cushioned shoes.
# Here are my 6 favorite pairs Delta flyers, don’t book another flight
# until you see these top cards for 2026 CNN Sports Carl
# Sandin/Bildbyrån/Reuters US Olympic hockey player distances himself
# from White House video trashing Canadians Courtesy of Museum of
# History & Industry - Al Smith Collection Unearthing the forgotten
# diamonds: The untold story of the Owls Club • CNN Exclusive CNN
# Exclusive John Walton/PA Images/Getty Images CNN Exclusive How family,
# focus and faith fuel Bukayo Saka and Arsenal’s trophy ambitions
# Bleacher Report Show all NFL scouting combine risers and fallers Alysa
# Liu links with ‘Harry Potter’ star Who is WWE targeting in 2026?
# Browns linked to ‘multiple’ QBs USA marathon championship ends in
# chaos Ad Feedback PAID PARTNER CONTENT Americans flock to 0% APR cards
# lasting until nearly 2028 CardCritics 0% Interest Until 2027 -- Plus
# $250 Bonuses! CardCritics US WJLA Man killed by state trooper after
# fatally stabbing a woman and a dog in road rage incident near DC Wales
# Hunter/Bowling Green Daily News/AP/File The hunt for who kidnapped and
# killed 7-year-old Morgan Violi was cold for decades. Then came a break
# Brynn Anderson/Pool/Getty Images Concerning texts and a case of
# mistaken identity. Colin Gray trial testimony reveals frantic moments
# before school shooting Politics Jose Luis Magana/AP Supreme Court
# signals it will back marijuana user who was charged with owning a gun
# Getty Images/Reuters Democratic challengers say incumbents aren’t
# fighting hard enough. This North Carolina primary will test that Joe
# Raedle/Getty Images/File How the Iran war set off a MAGA fight over
# Charlie Kirk’s legacy Business and economy Justin Sullivan/Getty
# Images HBO Max and Paramount+ will combine after WBD merger
# TrongNguyen/iStockphoto/Getty Images America’s teachers are working
# two jobs and barely getting by Bhawika Chhabra/Reuters The winners of
# the smartphone boom think they know what the next big tech gadget is
# CNN Shorts • Video 1:37 Getty Images Video Trump’s shift from talking
# about Iran to ballroom design 1:37 • Video 0:59 Nathan Comeaux Video
# Witness recounts Austin mass shooting 0:59 • Video 0:26 Fox News Video
# Savannah Guthrie lays flowers outside her mother’s home 0:26 • Video
# 1:46 Getty Images Video CNN poll reveals how Americans feel about
# strikes 1:46 • Video 3:44 CNN Video Tapper shares what Trump said on
# phone call 3:44 • Video 0:54 CNN Video Cruise ships stranded in Doha
# as travel grinds to a halt 0:54 • Video 1:09 CNN Video Iranian deputy
# FM on striking neighboring countries 1:09 • Video 1:41 Getty Images
# Video What to expect from gas prices as war spreads in the Middle East
# 1:41 • Video 0:36 CNN Video 'Significant escalation': Journalist on
# Qatar shooting down Iranian aircraft 0:36 • Video 0:45 Getty Images
# Video Stylist claims Zendaya and Tom Holland are married 0:45 • Video
# 0:48 POOL Video Trump says he won’t get bored with Iran conflict 0:48
# • Video 0:52 POOL Video Hegseth: This is not a so-called regime change
# war 0:52 • Video 1:28 CNN Video US-Iran war expands across region 1:28
# • Video 1:23 Reuters / Aramco Handout, CNN Video Oil prices surge amid
# violence in Middle East 1:23 • Video 0:31 CNN Video CNN witnesses
# Iranian drone flying overhead towards Iraq 0:31 • Video 1:10 Social
# media Video US military aircraft downed over Kuwait by ‘friendly fire’
# 1:10 • Video 0:27 @Farsna/Telegram Video Iranian state media shows off
# underground drone fleet 0:27 • Video 1:28 Truth Social /
# @realdonaldtrump Video How likely is a month-long war with Iran? 1:28
# • Video 0:34 CNN Video Explosions heard over Doha 0:34 • Video 1:25
# Social Media Video A new front opens up in expanding Middle East
# conflict 1:25 • Video 0:53 CNN Video Trump arrives at the White House,
# stops to admire the statues 0:53 • Video 1:16 CNN Video Gunshots ring
# out in Austin bar district 1:16 • Video 0:36 MDA Video Red alert
# sirens activated in Jerusalem after Iranian missile hits area 0:36 •
# Video 1:04 CNN Images Video Inside the precision strikes that
# shattered Iran’s leadership 1:04 • Video 0:59 Faytuks Network Video
# High-rise residential building struck by Iranian drone in Bahrain 0:59
# All there is CNN ‘Something broke in me’: Eric Church on how the Las
# Vegas shooting changed him CNN How do you talk to the kids in your
# life about grief? Share your thoughts • Streaming Now Streaming Now
# CNN Streaming Now Past episodes of All There Is Live Health and
# wellness Todd Holland/Stanford Medicine A smart brain implant could
# revolutionize Parkinson’s care How to stay strong as you age without
# injuring yourself US surpassed 1,100 measles cases in two months.
# Expect more deaths next World Yoan Valat/AP Macron says France will
# increase its nuclear warheads for the first time in decades Felipe
# Dana/AP/File Taliban allows men to beat their wives as long as they
# don’t break bones or leave open wounds Francesco Sforza/Vatican
# Media/Reuters How Pope Leo was elected: New details of dramatic
# conclave battle revealed Entertainment Brian Bowen Smith/Disney
# ‘Scrubs’ returns with a new heartbeat — and the same old heart • Video
# 2:10 EBOF Video Why are Americans loving JFK Jr. and Carolyn Bessette?
# 2:10 Mario Tama/Getty Images An old Pokémon card could have made me a
# fortune. Countless others are cashing in Travel Jeremy
# Woodhouse/Photodisc/Getty Images The 1,700-year-old megastructure
# history almost forgot AirBnB The cottage from ‘Heated Rivalry’ is on
# Airbnb Bolton Valley These low-key US mountains offer ways to avoid
# getting ‘priced out of skiing’ Food and drink • Streaming Now
# Streaming Now CNN Streaming Now Anthony Bourdain traveled the globe
# and celebrated diverse cultures by exploring food Kyle
# Goldberg/BFA.com/Shutterstock America is running out of Topo Chico
# mineral water Franziska Krug/Getty Images The world’s biggest food
# company doesn’t want to make ice cream anymore Chance Encounters
# Carrin Schottler-Thal She almost let the stranger walk out of her life
# for good. Then a royal bodyguard intervened Courtesy Claire Chabaud
# and David Redd She arrived in New York on Halloween. Then she met the
# guy of her dreams Amy B. Scher/Charlotte Phillips They were thousands
# of miles from home in a hospital in India. Here’s how they met and
# fell in love Science report Ramirez Buxeda/Orlando Sentinel/TNS/Getty
# Images NASA abruptly changes roadmap to putting boots back on moon
# Mike Kemp/In Pictures/In Pictures via Getty Images What happened when
# humans and Neanderthals hooked up Anthony Waddle From frog saunas to
# medicated baths: Scientists battle a global amphibian plague Fashion
# Daniele Venturelli/Getty Images Gucci asks: Can AI ever be luxury?
# Toby Shepheard/AFP/Getty Images David Beckham’s son walks Burberry
# fashion show • Video 2:15 AP Video How Prada is appealing to an
# unexpected crowd 2:15 Paid Content Paid Content Recommendations More
# from CNN Risk Takers Michael M. Santiago/Getty Images E.l.f. Beauty’s
# CEO wants to make a beauty empire for Gen Z Courtesy Victor Owen
# Schwartz While corporate America stayed silent, a small wine importer
# risked his business to challenge Trump’s tariffs Rodrigo De Medeiros
# Costco’s CEO is an unlikely risk taker CNN Videos • Video 2:11 CNN
# Video Parents are buying landlines instead of cell phones for their
# kids 2:11 • Video 1:29 Sammy Azdoufal Video He accidentally gained
# control of 7,000 robot vacuums 1:29 • Video 0:54 CNN Video Snowstorm
# didn’t stop this bride’s big day 0:54 Ad Feedback Paid Partner Content
# CNN Games + Quizzes • Sudoku Sudoku CNN Sudoku A cross-number
# crossword that will challenge your brain • Sudoblock Sudoblock CNN
# Sudoblock Sudoku + Blocks = addictive tile-matching puzzle • Today's
# crossword Today's crossword CNN Today's crossword No pencil or eraser
# required • Jumble Crossword Jumble Crossword CNN Jumble Crossword Test
# your smarts with this scrambled word game In case you missed it photo
# illustration by Alberto Mier/CNN A priest helped her see her drinking
# problem. Talks with Jesus kept her sober. She’s not the only one
# Donald Trump/Truth Social/Handout/Reuters Social media videos and
# surprise phone calls: How Trump told the world about Iran Mar 2, 2026
# Angel Garcia/Bloomberg/Getty Images Apple launches cheaper iPhone 17e
# in push to boost iPhone sales Mar 2, 2026 The White House/X Hunkered
# at Mar-a-Lago, Trump made his club a makeshift Situation Room Mar 1,
# 2026 CNN Video Have I Got News For You: Comedians take on the State of
# the Union 2:49 Mar 1, 2026 RODRIGO OROPEZA/AFP/AFP via Getty Images
# Rebuilding faces and identifying tattoos, AI joins the search for the
# missing in Mexico Mar 1, 2026 Subscribe Sign in My Account Settings
# Newsletters Topics you follow Sign out Your CNN account Sign in to
# your CNN account Listen Watch US Crime & Justice Immigration Education
# Transportation Race & Identity World Africa Americas Asia Australia
# China Europe India Middle East United Kingdom Politics Trump Facts
# First CNN Polls 2026 Elections Calendar Redistricting Tracker Epstein
# Files Business Tech Media Calculators Videos Markets Pre-markets
# After-Hours Fear & Greed Investing Markets Now Nightcap Health Life,
# But Better Fitness Food Sleep Mindfulness Relationships CNN
# Underscored Electronics Fashion Beauty Health & Fitness Home Reviews
# Deals Gifts Travel Outdoors Pets Entertainment Movies Television
# Celebrity Tech Innovate Style Arts Design Fashion Architecture Luxury
# Beauty Video Travel Destinations Food & Drink Stay News Videos Sports
# Pro Football College Football Basketball Baseball Soccer Olympics
# Hockey Science Space Life Unearthed Climate Solutions Weather Weather
# Video Climate Winter Olympics 2026 Ukraine-Russia War Israel-Hamas War
# Watch Featured Shows & Films Network TV Clips CNN Headlines CNN Shorts
# Shows A-Z CNN 10 CNN TV Schedules Listen CNN 5 Things Chasing Life
# with Dr. Sanjay Gupta The Assignment with Audie Cornish One Thing Tug
# of War CNN Political Briefing The Axe Files All There Is with Anderson
# Cooper All CNN Audio podcasts Games Daily Crossword Jumble Crossword
# Photo Shuffle Sudoblock Sudoku 5 Things Quiz About CNN Subscribe
# Photos Investigations CNN Profiles CNN Leadership CNN Newsletters Work
# for CNN Watch Listen Subscribe Sign in My Account Settings Newsletters
# Topics you follow Sign out Your CNN account Sign in to your CNN
# account Follow CNN Download the CNN app Download the CNN app Terms of
# Use Privacy Policy Do Not Sell Or Share My Personal Information Ad
# Choices Accessibility & CC About Subscribe Newsletters Transcripts
# Help Center © 2026 Cable News Network. A Warner Bros. Discovery
# Company. All Rights Reserved. CNN Sans ™ & © 2016 Cable News Network.
# Download the CNN app Scan the QR code to download the CNN app on
# Google Play. Download the CNN app Scan the QR code to download the CNN
# app from the Apple Store. Global Privacy Control (GPC) signal
# detected.  Your personal information will not be sold or shared. Do
# Not Sell or Share My Personal Data For residents of certain states
# only.  Please visit our U.S. State Supplement for more information.
# Privacy Policy Manage Consent Preferences Allow the Sale, Sharing or
# use of My Personal information for Targeted Advertising Allow the
# Sale, Sharing or use of My Personal information for Targeted
# Advertising If you switch this toggle to “no,” we will not sell or
# share your personal information with third parties for advertising
# targeted to this device. Please see our Privacy Center for additional
# preferences. Strictly Necessary Cookies Always Active These cookies
# are necessary for the website to function and cannot be switched off
# in our systems. You can set your browser to block or alert you about
# these cookies, but some parts of the site will not work. Back Button
# Cookie List Search Icon Filter Icon Clear checkbox label label Apply
# Cancel Consent Leg.Interest checkbox label label checkbox label label
# checkbox label label Confirm My Choices close dialog Stream the CNN
# experience. Get more with unlimited streaming, TV, 24/7 global news,
# and shows & films. Stream the CNN experience. Get more with unlimited
# streaming, TV, 24/7 global news, and shows & films. View plans View
# plans close dialog

# %%
all_tools = tools + [tool_push]

# %%
llm = ChatOpenAI(model="gpt-4o-mini")
llm_with_tools = llm.bind_tools(all_tools)


def chatbot(state: State):
    return {"messages": [llm_with_tools.invoke(state["messages"])]}

# %%
graph_builder = StateGraph(State)
graph_builder.add_node("chatbot", chatbot)
graph_builder.add_node("tools", ToolNode(tools=all_tools))
graph_builder.add_conditional_edges( "chatbot", tools_condition, "tools")
graph_builder.add_edge("tools", "chatbot")
graph_builder.add_edge(START, "chatbot")

memory = MemorySaver()
graph = graph_builder.compile(checkpointer=memory)
display(Image(graph.get_graph().draw_mermaid_png()))

# %%
config = {"configurable": {"thread_id": "10"}}

async def chat(user_input: str, history):
    result = await graph.ainvoke({"messages": [{"role": "user", "content": user_input}]}, config=config)
    return result["messages"][-1].content


gr.ChatInterface(chat, type="messages").launch()
# Out:
# * Running on local URL:  http://127.0.0.1:7860
# * To create a public link, set `share=True` in `launch()`.
# <div><iframe src="http://127.0.0.1:7860/" width="100%" height="500" allow="autoplay; camera; microphone; clipboard-read; clipboard-write;" frameborder="0" allowfullscreen></iframe></div>
